# %% [markdown]
# <a href="https://colab.research.google.com/github/alyssaweller/MIS2800/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The next six blocks provide the exact code to run to get your Colab file
# started to run SQLite3.

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# /bin/bash: line 1: pip install --upgrade pandas ipython-sql prettytable==3.10.1: command not found

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# /bin/bash: line 1: pip install ipython-sql: command not found
# ipython sql installed

# %%
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
#Block 1
# Instructions: There is a typo in the table.  Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# %%sql
-- Instructions: Fix the code to select all the columns from the Marketi
SELECT FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) no such column: FROM Marketing_Brands
# [SQL: -- Instructions: Fix the code to select all the columns from the Marketi
# SELECT FROM Marketing_Brands;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 4
# %%sql
-- Instructions: Fix the code to display only the brand names and brand
SELECT FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) no such column: FROM Marketing_Brands
# [SQL: -- Instructions: Fix the code to display only the brand names and brand
# SELECT FROM Marketing_Brands;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT FROM Marketing_Brands
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) no such column: FROM Marketing_Brands
# [SQL: -- Instructions: Fix the code to find the brand types that are Religious
# SELECT FROM Marketing_Brands]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 6
# %%sql
-- Instructions: Fix the code to display the brand names that have a bud
SELECT FROM Marketing_Brands
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) no such column: FROM Marketing_Brands
# [SQL: -- Instructions: Fix the code to display the brand names that have a bud
# SELECT FROM Marketing_Brands]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in Colab witho
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) no such table: Marketing_Brands
# [SQL: SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 8
# %%sql
--Instructions: Find the brands where the brand type is Snacks or Bevera
SELECT * FROM Marketing_Brands
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) near "FROM Marketing_Brands": syntax error
# [SQL: --Instructions: Find the brands where the brand type is Snacks or Bevera
# SELECT * FROM Marketing_Brands]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 9
# %%sql
-- Instructions: Sort the table by brand budget in DESC order. Display o
SELECT
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) incomplete input
# [SQL: -- Instructions: Sort the table by brand budget in DESC order. Display o
# SELECT]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a table showing all the co

# %% [markdown]
# Answer the Questions Below Based on the SQL Code
# You've Run Above
# 1. How did you fix the error in Block #1? Answer: Added TABLE after CREATE
# 2. How did you fix the error in Block #2? Answer: Added INTO after INSERT
# 3. How did you fix the error in Block #3? Answer: Added * between SELECT FROM
# 4. How did you fix the error in Block #4? Answer: Added brand_name and brand_type between SELECT FROM
# 5. How did you fix the error in Block #5? Answer: Added * and WHERE brand_type = religious
# 6. How did you fix the error in Block #6? Answer: Added brand_name between SELECT FROM
# 7. How did you fix the error in Block #7? Answer: Added %%sql
# 8. How did you fix the error in Block #8? Answer: Added WHERE brand_type = 'Snacks' OR brand_type = 'Beverages'
# 9. How did you fix the error in Block #9? Answer: Added * FROM Marketing_Brands ORDER BY brand_budget DESC;
# 10. How did you fix the error in Block #10? Answer: Added the whole code
